# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
crimeData = pd.read_csv("crimeDataWithPhase.csv")
yearList = [2008,2009,2010,2011,2012,2013,2014,2015]
yearData = [crimeData[(crimeData.DateOccured >= (str(x)+"-01-01")) & (crimeData.DateOccured < (str(x+1)+"-01-01"))] for x in yearList]

# %%
fullMoons = [yearData[x]["DateOccured"][yearData[x].Phase == "Full Moon"].count() for x in range(len(yearList))]
newMoons = [yearData[x]["DateOccured"][yearData[x].Phase == "New Moon"].count() for x in range(len(yearList))]
firstQuarters = [yearData[x]["DateOccured"][yearData[x].Phase == "First Quarter"].count() for x in range(len(yearList))]
lastQuarters = [yearData[x]["DateOccured"][yearData[x].Phase == "Last Quarter"].count() for x in range(len(yearList))]

# %%
years = np.array(yearList)
plt.plot(years, fullMoons, label="Full Moon")
plt.plot(years, newMoons, label="New Moon")
plt.plot(years, firstQuarters, label="First Quarter")
plt.plot(years, lastQuarters, label="Last Quarter")
plt.ylabel("Number of Crimes")
plt.xlabel("Year")
plt.grid()
plt.title("Crimes by Lunar Phase from 2008-2015")
plt.legend()
plt.savefig("crimesByLunarPhaseLine.png")
plt.show()

# %%
springDate = "-03-20"
summerDate = "-06-20"
autumnDate = "-09-22"
winterDate = "-12-21"
springCrimes = [yearData[x]["DateOccured"][(yearData[x].DateOccured >= str(x+2008)+springDate) & (yearData[x].DateOccured < str(x+2008)+summerDate)].count() for x in range(len(yearList)-1)]
summerCrimes = [yearData[x]["DateOccured"][(yearData[x].DateOccured >= str(x+2008)+summerDate) & (yearData[x].DateOccured < str(x+2008)+autumnDate)].count() for x in range(len(yearList)-1)]
autumnCrimes = [yearData[x]["DateOccured"][(yearData[x].DateOccured >= str(x+2008)+autumnDate) & (yearData[x].DateOccured < str(x+2008)+winterDate)].count() for x in range(len(yearList)-1)]
winterCrimes = [yearData[x]["DateOccured"][(yearData[x].DateOccured > str(x+2008)+winterDate)].count() + yearData[x+1]["DateOccured"][(yearData[x+1].DateOccured < str(x+2009)+springDate)].count() for x in range(len(yearList)-1)]
years = np.array([2008,2009,2010,2011,2012,2013,2014])
plt.plot(years, springCrimes, label="Spring")
plt.plot(years, summerCrimes, label="Summer")
plt.plot(years, autumnCrimes, label="Autumn")
plt.plot(years, winterCrimes, label="Winter")
plt.ylabel("Number of Crimes")
plt.xlabel("Year")
plt.grid()
plt.title("Crimes by Season from 2008-2014")
plt.legend()
plt.savefig("crimesBySeasonLine.png")
plt.show()

# %%
seasons = [sum(springCrimes), sum(summerCrimes), sum(autumnCrimes), sum(winterCrimes)]
botLabels = np.arange(len(seasons))
plt.xticks(botLabels, ["Spring", "Summer", "Autumn", "Winter"])
plt.title("Total Crimes by Season from 2008-2014")
plt.ylabel("Number of Crimes")
plt.xlabel("Season")
for h, v in enumerate(seasons):
    plt.text(h-.47, v+(v*.015), "{0} ({1:.1f}%)".format(v, v/sum(seasons)*100))
plt.bar(botLabels, seasons)
plt.savefig("totalCrimesBar.png")
plt.show()

# %%
crimeList = yearData[0]["UCRCrime"].unique()
lunarPhases = ["Full Moon", "New Moon", "First Quarter", "Last Quarter"]
fmLarceny = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[0]) & (yearData[x].Phase == "Full Moon")].count() for x in range(len(yearList))]
fmAssault = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[1]) & (yearData[x].Phase == "Full Moon")].count() for x in range(len(yearList))]
fmRape = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[2]) & (yearData[x].Phase == "Full Moon")].count() for x in range(len(yearList))]
fmBurglary = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[3]) & (yearData[x].Phase == "Full Moon")].count() for x in range(len(yearList))]
fmGTA = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[4]) & (yearData[x].Phase == "Full Moon")].count() for x in range(len(yearList))]
fmArson = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[5]) & (yearData[x].Phase == "Full Moon")].count() for x in range(len(yearList))]
fmRobbery = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[6]) & (yearData[x].Phase == "Full Moon")].count() for x in range(len(yearList))]
fmHomicide = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[7]) & (yearData[x].Phase == "Full Moon")].count() for x in range(len(yearList))]
# fullMoonCrimes = [sum(fmLarceny), sum(fmAssault), sum(fmRape), sum(fmBurglary), sum(fmGTA), sum(fmArson), sum(fmRobbery), sum(fmHomicide)]
nmlarceny = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[0]) & (yearData[x].Phase == "New Moon")].count() for x in range(len(yearList))]
nmassault = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[1]) & (yearData[x].Phase == "New Moon")].count() for x in range(len(yearList))]
nmrape = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[2]) & (yearData[x].Phase == "New Moon")].count() for x in range(len(yearList))]
nmburglary = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[3]) & (yearData[x].Phase == "New Moon")].count() for x in range(len(yearList))]
nmGTA = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[4]) & (yearData[x].Phase == "New Moon")].count() for x in range(len(yearList))]
nmarson = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[5]) & (yearData[x].Phase == "New Moon")].count() for x in range(len(yearList))]
nmrobbery = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[6]) & (yearData[x].Phase == "New Moon")].count() for x in range(len(yearList))]
nmhomicide = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[7]) & (yearData[x].Phase == "New Moon")].count() for x in range(len(yearList))]
# newMoonCrimes = [sum(nmlarceny), sum(nmassault), sum(nmrape), sum(nmburglary), sum(nmGTA), sum(nmarson), sum(nmrobbery), sum(nmhomicide)]
fqLarceny = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[0]) & (yearData[x].Phase == "First Quarter")].count() for x in range(len(yearList))]
fqAssault = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[1]) & (yearData[x].Phase == "First Quarter")].count() for x in range(len(yearList))]
fqRape = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[2]) & (yearData[x].Phase == "First Quarter")].count() for x in range(len(yearList))]
fqBurglary = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[3]) & (yearData[x].Phase == "First Quarter")].count() for x in range(len(yearList))]
fqGTA = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[4]) & (yearData[x].Phase == "First Quarter")].count() for x in range(len(yearList))]
fqArson = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[5]) & (yearData[x].Phase == "First Quarter")].count() for x in range(len(yearList))]
fqRobbery = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[6]) & (yearData[x].Phase == "First Quarter")].count() for x in range(len(yearList))]
fqHomicide = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[7]) & (yearData[x].Phase == "First Quarter")].count() for x in range(len(yearList))]
# fqMoonCrimes = [sum(fqLarceny), sum(fqAssault), sum(fqRape), sum(fqBurglary), sum(fqGTA), sum(fqArson), sum(fqRobbery), sum(fqHomicide)]
lqLarceny = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[0]) & (yearData[x].Phase == "Last Quarter")].count() for x in range(len(yearList))]
lqAssault = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[1]) & (yearData[x].Phase == "Last Quarter")].count() for x in range(len(yearList))]
lqRape = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[2]) & (yearData[x].Phase == "Last Quarter")].count() for x in range(len(yearList))]
lqBurglary = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[3]) & (yearData[x].Phase == "Last Quarter")].count() for x in range(len(yearList))]
lqGTA = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[4]) & (yearData[x].Phase == "Last Quarter")].count() for x in range(len(yearList))]
lqArson = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[5]) & (yearData[x].Phase == "Last Quarter")].count() for x in range(len(yearList))]
lqRobbery = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[6]) & (yearData[x].Phase == "Last Quarter")].count() for x in range(len(yearList))]
lqHomicide = [yearData[x]["UCRCrime"][(yearData[x].UCRCrime == crimeList[7]) & (yearData[x].Phase == "Last Quarter")].count() for x in range(len(yearList))]
# lqMoonCrimes = [sum(lqLarceny), sum(lqAssault), sum(lqRape), sum(lqBurglary), sum(lqGTA), sum(lqArson), sum(lqRobbery), sum(lqHomicide)]
larceny = [sum(fmLarceny), sum(nmlarceny), sum(fqLarceny), sum(lqLarceny)]
assault = [sum(fmAssault), sum(nmassault), sum(fqAssault), sum(lqAssault)]
rape = [sum(fmRape), sum(nmrape), sum(fqRape), sum(lqRape)]
burglary = [sum(fmBurglary), sum(nmburglary), sum(fqBurglary), sum(lqBurglary)]
GTA = [sum(fmGTA), sum(nmGTA), sum(fqGTA), sum(lqGTA)]
arson = [sum(fmArson), sum(nmarson), sum(fqArson), sum(lqArson)]
robbery = [sum(fmRobbery), sum(nmrobbery), sum(fqRobbery), sum(lqRobbery)]
homicide = [sum(fmHomicide), sum(nmhomicide), sum(fqHomicide), sum(lqHomicide)]
phases = np.array([1,2,3,4])
plt.figure(figsize=(9,6))
plt.plot(phases, larceny, label="Larceny")
plt.plot(phases, assault, label="Assault")
plt.plot(phases, rape, label="Rape")
plt.plot(phases, burglary, label="Burglary")
plt.plot(phases, GTA, label="Motor Vehicle Theft")
plt.plot(phases, arson, label="Arson")
plt.plot(phases, robbery, label="Robbery")
plt.plot(phases, homicide, label="Homicide")
plt.ylabel("Number of Crimes")
plt.xlabel("Year")
plt.xticks(phases, lunarPhases)
plt.grid()
plt.title("Crimes by Phase")
plt.legend(bbox_to_anchor=(1, 1))
plt.savefig("crimeByPhase.png")
plt.show()
